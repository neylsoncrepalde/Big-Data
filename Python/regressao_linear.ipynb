# %% [markdown]
# # Testes com Python - Regressão Linear
#
# Fazendo alguns testes com modelos de regressão.

# %%
# %matplotlib inline
import scipy as sp
import pandas as pd
import matplotlib.pyplot as plt
import statsmodels.formula.api as sm

x = sp.random.normal(size=100)
z = sp.random.normal(size=100)
categoria = sp.random.binomial(n=1, p=.5, size=100)
erro = sp.random.normal(size=100)

y = 3 + 2*x + 0.65*z + 1.5*categoria + erro
y
# Out:
# array([ 0.85977431,  0.44675716,  7.1705348 ,  1.17536293,  3.19298847,
#         3.6410201 ,  5.1308661 ,  2.76600542,  1.14860244,  5.05519069,
#         4.75152639,  6.51351327,  0.94050759,  4.98737799,  5.89833699,
#         3.1259248 ,  3.42192464,  5.72833641,  4.51234478,  4.90844548,
#         7.83270295,  4.04571286,  0.25630105,  3.16000449,  1.51837325,
#         5.72968279,  2.90166743,  1.51227161,  6.13270856, -0.95874162,
#        -1.25015101,  7.33811587, -0.67671775,  5.48251197,  5.65909354,
#         5.99125981,  5.1616144 ,  1.31143503, -1.61601662,  2.90976628,
#        -1.42475645,  2.39491224,  5.45977912,  5.8343752 ,  9.04935863,
#         6.82001029,  3.55985079,  2.43761196,  2.7912839 ,  4.35406866,
#         7.64154219,  1.85251058,  4.72306474,  0.69656842,  1.00864474,
#         7.58535543,  4.74461562,  2.93318487,  0.6482081 ,  9.52257343,
#         3.4192706 ,  7.6965518 ,  5.97583811,  3.65076973,  4.25864135,
# ...

# %%
plt.hist(y, color='red')
plt.title('Histograma da variável resposta')
plt.show()

# %%
# Montando um modelinho de regressão
dic = {"y":y, "x":x, "categoria":categoria}
dados = pd.DataFrame(data=dic)
dados
# Out:
#     categoria         x          y
# 0           0  0.180367   2.246173
# 1           0  0.738473   4.153146
# 2           0  0.561535   4.591526
# 3           1  0.134268   3.916696
# 4           1 -0.390301   4.273898
# 5           1 -0.050457   5.878414
# 6           0 -0.057868   1.852130
# 7           0  0.415228   4.921270
# 8           1  1.385472   8.402714
# 9           1 -0.123582   4.931893
# 10          1  0.167312   6.195231
# 11          1  0.986653   8.089632
# 12          0  0.645910   2.445135
# 13          0 -0.602552  -0.222077
# 14          1 -0.038658   3.262755
# 15          1  1.227873   8.091323
# 16          1 -1.465346   1.508739
# 17          0 -0.895404   2.256637
# 18          1 -0.911087   2.536766
# 19          1  0.857483   6.481431
# 20          0  0.093992   2.710780
# 21          1 -0.284098   4.589097
# 22          1 -2.003089  -0.399736
# 23          1  0.089747   4.499094
# 24          1 -0.256763   2.298255
# 25          1 -1.999937   0.738825
# ...

# %%
reg = sm.ols(formula='y~x+categoria', data=dados).fit()
reg.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.836
# Model:                            OLS   Adj. R-squared:                  0.833
# Method:                 Least Squares   F-statistic:                     247.9
# Date:                Qui, 06 Out 2016   Prob (F-statistic):           7.40e-39
# Time:                        13:20:38   Log-Likelihood:                -136.70
# No. Observations:                 100   AIC:                             279.4
# Df Residuals:                      97   BIC:                             287.2
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept      2.7214      0.144     18.904      0.000         2.436     3.007
# ...
